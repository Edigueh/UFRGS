# %% [markdown]
# # Learning
#
# This notebook is about a beginner in notebooks for ML using *Jupyter*.

# %% [markdown]
# ## Example 1: Hello, World

# %%
my_name = "André"

hello = "Hello, " + my_name

print(hello)

x = 10
# Out:
# Hello, André

# %% [markdown]
# ## Example 2: Loop

# %%
for j in range (1,10):
    x += j
    print(f"j={j}, x={x}")
# Out:
# j=1, x=11
# j=2, x=13
# j=3, x=16
# j=4, x=20
# j=5, x=25
# j=6, x=31
# j=7, x=38
# j=8, x=46
# j=9, x=55
